# %%
from pathlib import Path
from cmi_dss_lib.utils.visualize import Plotter
path_data = Path("../../../data")
import numpy as np

# %%
data = np.load(path_data/"eda/predicted-fold_2.npz")

# %%
plot_cls = Plotter(data=data,post_process_modes=None)
# Out:
# self.score = 0.7098

# %%
plot_cls.plot(series_id='fb223ed2278c')
# Out:
# (921600, 3)
# /home/jumpei.uchida/develop/child-mind-institute-detect-sleep-states/lib/kaggle-child-mind-institute-detect-sleep-states/cmi_dss_lib/utils/visualize.py:139: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
